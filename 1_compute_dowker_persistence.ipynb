# %% [markdown]
# # Dowker persistence example
# * This notebook shows an example computation of Dowker persistence.

# %%
include("dowker_persistence.jl")
using .Dowker
using Eirene
using Plots
using CSV
using Distances
using DelimitedFiles
using JLD
using PersistenceDiagrams
# Out:
# WebIO._IJuliaInit()
# ┌ Warning: ORCA.jl has been deprecated and all savefig functionality
# │ has been implemented directly in PlotlyBase itself.
# │
# │ By implementing in PlotlyBase.jl, the savefig routines are automatically
# │ available to PlotlyJS.jl also.
# └ @ ORCA /Users/irisyoon/.julia/packages/ORCA/U5XaN/src/ORCA.jl:8

# %% [markdown]
# # 1. Compute Dowker persistence

# %% [markdown]
# ### Load example points

# %%
# load points
P1 = readdlm("toy_example/R1_coordinates.csv", ',', Float64)
P2 = readdlm("toy_example/R2_coordinates.csv", ',', Float64);

# %%
# plot
plot_P_Q(P1, P2; 
        P_label = "P1", 
        Q_label = "P2",
        aspect_ratio = :equal, )
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-1.54.2.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="426cfee7-ecd4-4440-98d7-f13b422bad22" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('426cfee7-ecd4-4440-98d7-f13b422bad22');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.08452389564043206,
#             0.21718267746913578,
#             0.2588011188271605,
#             0.3186276282793209,
#             0.4564887152777778,
#             0.7972397038966047,
#             0.8336558400848765,
#             1.000129605516975,
#             0.5370370370370371,
#             0.0679012345679012,
#             0.006172839506172756
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P1",
#         "zmin": null,
#         "legendgroup": "P1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.2634142515358473,
#             0.6275557572919613,
#             -0.10047657062191462,
#             0.1858562210280017,
#             0.8687282710012016,
#             0.8226024889044977,
#             -0.00857497065986923,
#             0.49247452801780023,
#             -0.04537743850720943,
#             -0.07044576382998757,
#             0.0865611158232027
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.01851851851851849,
#             0.12962962962962954,
#             0.44444444444444453,
#             0.7469135802469132,
#             0.27777777777777757,
#             0.7160493827160493,
#             0.9753086419753086,
#             0.9814814814814813,
#             0.5617283950617283,
#             0.7654320987654321,
#             1.2283950617283947,
#             1.5617283950617282,
#             1.5370370370370368,
#             1.2716049382716048,
#             0.9135802469135802
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P2",
#         "zmin": null,
#         "legendgroup": "P2",
#         "marker": {
#             "symbol": "x",
#             "color": "rgba(255, 141, 0, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.5452360757704271,
#             0.03972292903590624,
#             -0.22589765337856926,
#             -0.24790311940439147,
#             0.9407690132880973,
#             0.9565545188954858,
#             0.7261332579398738,
#             0.161577608142494,
#             -0.47153896899443937,
#             -0.7965319008576,
#             -1.000801055508434,
#             -0.6852794270097067,
#             -0.15224766751484275,
#             0.1541796249175389,
#             -1.05579116011686
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "range": [
#             -0.8265724626902674,
#             2.3944736972581686
#         ],
#         "domain": [
#             0.006561679790026247,
#             0.9934383202099737
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [],
#         "range": [
#             -1.1161615304872303,
#             1.0169248892658562
#         ],
#         "domain": [
#             0.00984251968503937,
#             0.9901574803149606
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "borderwidth": 1,
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# ### Compute distance matrices

# %%
D1, D2, D_P1_P2, D_P2_P1 = compute_distance(P1, P2);

# %% [markdown]
# ### Compute (usual) Vietoris-Rips persistence

# %%
C1 = eirene(D1)
C1_barcode = Eirene.barcode(C1, dim = 1)
C2 = eirene(D2)
C2_barcode = Eirene.barcode(C2, dim = 1);

# %%
p1 = plot_PD(C1_barcode, title = "P1")
p2 = plot_PD(C2_barcode, title = "P2")
plot(p1, p2, layout = grid(1,2))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="3a56ba06-6ff0-488c-8137-47f0e337447b" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('3a56ba06-6ff0-488c-8137-47f0e337447b');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             1,
#             2
#         ],
#         "x": [
#             0.2925161171752145,
#             0.5279811688898433
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(128, 128, 128, 0.500)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 0.500)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.3278528830815808,
#             0.7473016333182487
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.2340128937401716,
#             0.8220317966500736
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(128, 128, 128, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.2340128937401716,
#             0.8220317966500736
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "text": [
#             1,
#             2
#         ],
#         "x": [
#             0.5336033356260945,
#             0.5645893956369625
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(128, 128, 128, 0.500)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 0.500)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.9029411504621014,
#             1.0365768123110908
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             0.42688266850087564,
#             1.1402344935422
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(128, 128, 128, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.42688266850087564,
#             1.1402344935422
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "xaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8
#         ],
#         "range": [
#             0.2340128937401716,
#             0.8220317966500736
#         ],
#         "domain": [
#             0.05100612423447069,
#             0.4934383202099738
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.3",
#             "0.4",
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "bottom",
#         "xanchor": "right",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "tracegroupgap": 0,
#         "y": 0.07,
#         "borderwidth": 1,
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "height": 400,
#     "yaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8,
#             0.9,
#             1.0,
#             1.1
#         ],
#         "range": [
#             0.42688266850087564,
#             1.1402344935422
#         ],
#         "domain": [
#             0.15775918635170602,
#             0.8214074803149608
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8",
#             "0.9",
#             "1.0",
#             "1.1"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x2",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "xaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8,
#             0.9,
#             1.0,
#             1.1
#         ],
#         "range": [
#             0.42688266850087564,
#             1.1402344935422
#         ],
#         "domain": [
#             0.5510061242344708,
#             0.9934383202099739
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8",
#             "0.9",
#             "1.0",
#             "1.1"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y2",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "yaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,

# %% [markdown]
# ### Compute Dowker persistence

# %%
W_P1_P2 = compute_Witness_persistence(D_P1_P2, maxdim = 1)
W_barcode = Eirene.barcode(W_P1_P2["eirene_output"], dim = 1);

# %%
# plot Dowker persistence diagram
p = plot_PD(W_barcode, title = "Dowker persistence diagram")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="8da74af0-cd9b-4c19-b3e5-407b77148230" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('8da74af0-cd9b-4c19-b3e5-407b77148230');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             1
#         ],
#         "x": [
#             0.3314219728880507
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(128, 128, 128, 0.500)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 0.500)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.7560172181927687
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(128, 128, 128, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8
#         ],
#         "range": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "domain": [
#             0.2209135316418781,
#             0.8235309128025663
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.3",
#             "0.4",
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Dowker persistence diagram",
#             "xref": "paper",
#             "x": 0.5222222222222223
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8
#         ],
#         "range": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "domain": [
#             0.03762029746281716,
#             0.9415463692038496
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.3",
#             "0.4",
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "bottom",
#         "xanchor": "right",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "tracegroupgap": 0,
#         "y": 0.07,
#         "borderwidth": 1,
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# Plot a cycle representative of the Dowker persistence diagram

# %%
# get cycle representative
cr = get_Witness_cyclerep(W_P1_P2, class_num = 1);

# %%
plot_cycle(P1, P2, cycle = cr; aspect_ratio = :equal, P_label = "P1", Q_label = "P2")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="d69b818b-c274-4051-9b51-d462dcd0589a" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('d69b818b-c274-4051-9b51-d462dcd0589a');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.08452389564043206,
#             0.21718267746913578,
#             0.2588011188271605,
#             0.3186276282793209,
#             0.4564887152777778,
#             0.7972397038966047,
#             0.8336558400848765,
#             1.000129605516975,
#             0.5370370370370371,
#             0.0679012345679012,
#             0.006172839506172756
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P1",
#         "zmin": null,
#         "legendgroup": "P1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.2634142515358473,
#             0.6275557572919613,
#             -0.10047657062191462,
#             0.1858562210280017,
#             0.8687282710012016,
#             0.8226024889044977,
#             -0.00857497065986923,
#             0.49247452801780023,
#             -0.04537743850720943,
#             -0.07044576382998757,
#             0.0865611158232027
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.01851851851851849,
#             0.12962962962962954,
#             0.44444444444444453,
#             0.7469135802469132,
#             0.27777777777777757,
#             0.7160493827160493,
#             0.9753086419753086,
#             0.9814814814814813,
#             0.5617283950617283,
#             0.7654320987654321,
#             1.2283950617283947,
#             1.5617283950617282,
#             1.5370370370370368,
#             1.2716049382716048,
#             0.9135802469135802
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P2",
#         "zmin": null,
#         "legendgroup": "P2",
#         "marker": {
#             "symbol": "x",
#             "color": "rgba(255, 141, 0, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.5452360757704271,
#             0.03972292903590624,
#             -0.22589765337856926,
#             -0.24790311940439147,
#             0.9407690132880973,
#             0.9565545188954858,
#             0.7261332579398738,
#             0.161577608142494,
#             -0.47153896899443937,
#             -0.7965319008576,
#             -1.000801055508434,
#             -0.6852794270097067,
#             -0.15224766751484275,
#             0.1541796249175389,
#             -1.05579116011686
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.4564887152777778,
#             0.7972397038966047
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.8687282710012016,
#             0.8226024889044977
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.2588011188271605,
#             0.5370370370370371
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             -0.10047657062191462,
#             -0.04537743850720943
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.8336558400848765,
#             0.5370370370370371
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             -0.00857497065986923,
#             -0.04537743850720943
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.08452389564043206,
#             0.2588011188271605
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.2634142515358473,
#             -0.10047657062191462
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.7972397038966047,
#             1.000129605516975
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.8226024889044977,
#             0.49247452801780023
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.08452389564043206,
#             0.21718267746913578
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.2634142515358473,
#             0.6275557572919613
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.21718267746913578,
#             0.4564887152777778
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.6275557572919613,
#             0.8687282710012016
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.8336558400848765,
#             1.000129605516975
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin"

# %% [markdown]
# ### Compute persistence image

# %%
# convert format of barcodes from array to persistencediagram 
n = size(W_barcode,1)
W_diag = PersistenceDiagram([(W_barcode[i,1], W_barcode[i,2]) for i = 1:n])

C1_diag = PersistenceDiagram([(C1_barcode[i,1], C1_barcode[i,2]) for i = 1:size(C1_barcode,1)])
C2_diag = PersistenceDiagram([(C2_barcode[i,1], C2_barcode[i,2]) for i = 1:size(C2_barcode,2)]);

# %%
PI = PersistenceDiagrams.PersistenceImage([W_diag, C1_diag, C2_diag],
    sigma = 0.05,
    size = 100)
# Out:
# 100×100 PersistenceImage(
#   distribution = PersistenceDiagrams.Binormal(0.05),
#   weight = PersistenceDiagrams.DefaultWeightingFunction(0.47198741667412825),
# )

# %%
p1 = heatmap(PI(C1_diag), title = "VR(P1)")
p2 = heatmap(PI(C2_diag), title = "VR(P2)")
p3 = heatmap(PI(W_diag), title = "W(P1, P2)")
plot(p1, p2, p3, layout = grid(1,3), size = (800, 300))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="5ea91fce-ea92-40e4-99f8-3675c6e6809c" style="width:800px;height:300px;"></div>
#     <script>
#     PLOT = document.getElementById('5ea91fce-ea92-40e4-99f8-3675c6e6809c');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
#                 "rgba(2, 1, 10, 1.000)"
#             ],
#             [
#                 0.0196078431372549,
#                 "rgba(2, 2, 12, 1.000)"
#             ],
#             [
#                 0.023529411764705882,
#                 "rgba(2, 2, 14, 1.000)"
#             ],
#             [
#                 0.027450980392156862,
#                 "rgba(3, 2, 16, 1.000)"
#             ],
#             [
#                 0.03137254901960784,
#                 "rgba(4, 3, 18, 1.000)"
#             ],
#             [
#                 0.03529411764705882,
#                 "rgba(4, 3, 20, 1.000)"
#             ],
#             [
#                 0.0392156862745098,
#                 "rgba(5, 4, 23, 1.000)"
#             ],
#             [
#                 0.043137254901960784,
#                 "rgba(6, 4, 25, 1.000)"
#             ],
#             [
#                 0.047058823529411764,
#                 "rgba(7, 5, 27, 1.000)"
#             ],
#             [
#                 0.050980392156862744,
#                 "rgba(8, 5, 29, 1.000)"
#             ],
#             [
#                 0.054901960784313725,
#                 "rgba(9, 6, 31, 1.000)"
#             ],
#             [
#                 0.058823529411764705,
#                 "rgba(10, 7, 34, 1.000)"
#             ],
#             [
#                 0.06274509803921569,
#                 "rgba(11, 7, 36, 1.000)"
#             ],
#             [
#                 0.06666666666666667,
#                 "rgba(12, 8, 38, 1.000)"
#             ],
#             [
#                 0.07058823529411765,
#                 "rgba(13, 8, 41, 1.000)"
#             ],
#             [
#                 0.07450980392156863,
#                 "rgba(14, 9, 43, 1.000)"
#             ],
#             [
#                 0.0784313725490196,
#                 "rgba(16, 9, 45, 1.000)"
#             ],
#             [
#                 0.08235294117647059,
#                 "rgba(17, 10, 48, 1.000)"
#             ],
#             [
#                 0.08627450980392157,
#                 "rgba(18, 10, 50, 1.000)"
#             ],
#             [
#                 0.09019607843137255,
#                 "rgba(20, 11, 52, 1.000)"
#             ],
#             [
#                 0.09411764705882353,
#                 "rgba(21, 11, 55, 1.000)"
#             ],
#             [
#                 0.09803921568627451,
#                 "rgba(22, 11, 57, 1.000)"
#             ],
#             [
#                 0.10196078431372549,
#                 "rgba(24, 12, 60, 1.000)"
#             ],
#             [
#                 0.10588235294117647,
#                 "rgba(25, 12, 62, 1.000)"
#             ],
#             [
#                 0.10980392156862745,
#                 "rgba(27, 12, 65, 1.000)"
#             ],
#             [
#                 0.11372549019607843,
#                 "rgba(28, 12, 67, 1.000)"
#             ],
#             [
#                 0.11764705882352941,
#                 "rgba(30, 12, 69, 1.000)"
#             ],
#             [
#                 0.12156862745098039,
#                 "rgba(31, 12, 72, 1.000)"
#             ],
#             [
#                 0.12549019607843137,
#                 "rgba(33, 12, 74, 1.000)"
#             ],
#             [
#                 0.12941176470588237,
#                 "rgba(35, 12, 76, 1.000)"
#             ],
#             [
#                 0.13333333333333333,
#                 "rgba(36, 12, 79, 1.000)"
#             ],
#             [
#                 0.13725490196078433,
#                 "rgba(38, 12, 81, 1.000)"
#             ],
#             [
#                 0.1411764705882353,
#                 "rgba(40, 11, 83, 1.000)"
#             ],
#             [
#                 0.1450980392156863,
#                 "rgba(41, 11, 85, 1.000)"
#             ],
#             [
#                 0.14901960784313725,
#                 "rgba(43, 11, 87, 1.000)"
#             ],
#             [
#                 0.15294117647058825,
#                 "rgba(45, 11, 89, 1.000)"
#             ],
#             [
#                 0.1568627450980392,
#                 "rgba(47, 10, 91, 1.000)"
#             ],
#             [
#                 0.1607843137254902,
#                 "rgba(49, 10, 92, 1.000)"
#             ],
#             [
#                 0.16470588235294117,
#                 "rgba(50, 10, 94, 1.000)"
#             ],
#             [
#                 0.16862745098039217,
#                 "rgba(52, 10, 95, 1.000)"
#             ],
#             [
#                 0.17254901960784313,
#                 "rgba(54, 9, 97, 1.000)"
#             ],
#             [
#                 0.17647058823529413,
#                 "rgba(56, 9, 98, 1.000)"
#             ],
#             [
#                 0.1803921568627451,
#                 "rgba(57, 9, 99, 1.000)"
#             ],
#             [
#                 0.1843137254901961,
#                 "rgba(59, 9, 100, 1.000)"
#             ],
#             [
#                 0.18823529411764706,
#                 "rgba(61, 9, 101, 1.000)"
#             ],
#             [
#                 0.19215686274509805,
#                 "rgba(62, 9, 102, 1.000)"
#             ],
#             [
#                 0.19607843137254902,
#                 "rgba(64, 10, 103, 1.000)"
#             ],
#             [
#                 0.2,
#                 "rgba(66, 10, 104, 1.000)"
#             ],
#             [
#                 0.20392156862745098,
#                 "rgba(68, 10, 104, 1.000)"
#             ],
#             [
#                 0.20784313725490197,
#                 "rgba(69, 10, 105, 1.000)"
#             ],
#             [
#                 0.21176470588235294,
#                 "rgba(71, 11, 106, 1.000)"
#             ],
#             [
#                 0.21568627450980393,
#                 "rgba(73, 11, 106, 1.000)"
#             ],
#             [
#                 0.2196078431372549,
#                 "rgba(74, 12, 107, 1.000)"
#             ],
#             [
#                 0.2235294117647059,
#                 "rgba(76, 12, 107, 1.000)"
#             ],
#             [
#                 0.22745098039215686,
#                 "rgba(77, 13, 108, 1.000)"
#             ],
#             [
#                 0.23137254901960785,
#                 "rgba(79, 13, 108, 1.000)"
#             ],
#             [
#                 0.23529411764705882,
#                 "rgba(81, 14, 108, 1.000)"
#             ],
#             [
#                 0.23921568627450981,
#                 "rgba(82, 14, 109, 1.000)"
#             ],
#             [
#                 0.24313725490196078,
#                 "rgba(84, 15, 109, 1.000)"
#             ],
#             [
#                 0.24705882352941178,
#                 "rgba(85, 15, 109, 1.000)"
#             ],
#             [
#                 0.25098039215686274,
#                 "rgba(87, 16, 110, 1.000)"
#             ],
#             [
#                 0.2549019607843137,
#                 "rgba(89, 16, 110, 1.000)"
#             ],
#             [
#                 0.25882352941176473,
#                 "rgba(90, 17, 110, 1.000)"
#             ],
#             [
#                 0.2627450980392157,
#                 "rgba(92, 18, 110, 1.000)"
#             ],
#             [
#                 0.26666666666666666,
#                 "rgba(93, 18, 110, 1.000)"
#             ],
#             [
#                 0.2705882352941176

# %% [markdown]
# # 2. Dowker duality
# * Note that the input to Witness persistence above was D_P1_P2, where the rows correspond to P1 and the columns correspond to P2.
# * What happens if we compute the Witness persistence using the transpose of D_P1_P2?
#     * Let D_P2_P1 be the transpose
#     * Rows: P2
#     * Columns: P1
#     * The result should be the same

# %% [markdown]
# Compute Dowker persistence

# %%
W_P2_P1 = compute_Witness_persistence(D_P2_P1, maxdim = 1)
W_barcode = Eirene.barcode(W_P2_P1["eirene_output"], dim = 1);

# %%
# plot Dowker persistence diagram
p = plot_PD(W_barcode, title = "")
plot(p)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="4e65091e-cac0-446d-adb4-933a12be2747" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('4e65091e-cac0-446d-adb4-933a12be2747');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             1
#         ],
#         "x": [
#             0.3314219728880507
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(128, 128, 128, 0.500)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 0.500)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.7560172181927687
#         ],
#         "type": "scatter",
#         "hoverinfo": "text"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(128, 128, 128, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8
#         ],
#         "range": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "domain": [
#             0.20470982793817444,
#             0.83973461650627
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.3",
#             "0.4",
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.30000000000000004,
#             0.4,
#             0.5,
#             0.6000000000000001,
#             0.7000000000000001,
#             0.8
#         ],
#         "range": [
#             0.26513757831044055,
#             0.8316189400120456
#         ],
#         "domain": [
#             0.03762029746281716,
#             0.9901574803149606
#         ],
#         "mirror": true,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0.3",
#             "0.4",
#             "0.5",
#             "0.6",
#             "0.7",
#             "0.8"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "legend": {
#         "yanchor": "bottom",
#         "xanchor": "right",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "tracegroupgap": 0,
#         "y": 0.07,
#         "borderwidth": 1,
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#     </script>
#
#     </body>
# </html>

# %%
# get cycle representative
cr_P2_P1 = get_Witness_cyclerep(W_P2_P1, class_num = 1);

# %%
plot_cycle(P1, P2, cycle = cr_P2_P1; aspect_ratio = :equal, cycle_loc = "Q", P_label = "P1", Q_label = "P2")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-1.54.2.min.js"></script>
#     </head>
#     <body>
#             <div id="e7e91c97-7dae-4953-8acf-4dcdc69f7380" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('e7e91c97-7dae-4953-8acf-4dcdc69f7380');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.08452389564043206,
#             0.21718267746913578,
#             0.2588011188271605,
#             0.3186276282793209,
#             0.4564887152777778,
#             0.7972397038966047,
#             0.8336558400848765,
#             1.000129605516975,
#             0.5370370370370371,
#             0.0679012345679012,
#             0.006172839506172756
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P1",
#         "zmin": null,
#         "legendgroup": "P1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 129, 129, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.2634142515358473,
#             0.6275557572919613,
#             -0.10047657062191462,
#             0.1858562210280017,
#             0.8687282710012016,
#             0.8226024889044977,
#             -0.00857497065986923,
#             0.49247452801780023,
#             -0.04537743850720943,
#             -0.07044576382998757,
#             0.0865611158232027
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.01851851851851849,
#             0.12962962962962954,
#             0.44444444444444453,
#             0.7469135802469132,
#             0.27777777777777757,
#             0.7160493827160493,
#             0.9753086419753086,
#             0.9814814814814813,
#             0.5617283950617283,
#             0.7654320987654321,
#             1.2283950617283947,
#             1.5617283950617282,
#             1.5370370370370368,
#             1.2716049382716048,
#             0.9135802469135802
#         ],
#         "showlegend": true,
#         "mode": "markers",
#         "name": "P2",
#         "zmin": null,
#         "legendgroup": "P2",
#         "marker": {
#             "symbol": "x",
#             "color": "rgba(255, 141, 0, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 10
#         },
#         "zmax": null,
#         "y": [
#             0.5452360757704271,
#             0.03972292903590624,
#             -0.22589765337856926,
#             -0.24790311940439147,
#             0.9407690132880973,
#             0.9565545188954858,
#             0.7261332579398738,
#             0.161577608142494,
#             -0.47153896899443937,
#             -0.7965319008576,
#             -1.000801055508434,
#             -0.6852794270097067,
#             -0.15224766751484275,
#             0.1541796249175389,
#             -1.05579116011686
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.27777777777777757,
#             0.7160493827160493
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.9407690132880973,
#             0.9565545188954858
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.7160493827160493,
#             0.9753086419753086
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.9565545188954858,
#             0.7261332579398738
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.12962962962962954,
#             0.44444444444444453
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.03972292903590624,
#             -0.22589765337856926
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.01851851851851849,
#             0.12962962962962954
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.5452360757704271,
#             0.03972292903590624
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.7469135802469132,
#             0.9814814814814813
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             -0.24790311940439147,
#             0.161577608142494
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.01851851851851849,
#             0.27777777777777757
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             0.5452360757704271,
#             0.9407690132880973
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.44444444444444453,
#             0.7469135802469132
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(255, 20, 147, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 5
#         },
#         "y": [
#             -0.22589765337856926,
#             -0.24790311940439147
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.9753086419753086,
#             0.9814814814814813
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "z

# %% [markdown]
# * Using the transpose matrix `D_P2_P1` results in the same Dowker barcodes.
# * Based on the cycle representatives, one can see that the Dowker barcode picks out common / shared features between P1 and P2
